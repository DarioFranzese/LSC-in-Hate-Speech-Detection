# %%
from datasets import load_dataset

old = load_dataset('parquet', data_dir='./mydatasets/Old', split='train')
modern = load_dataset('parquet', data_dir='./mydatasets/Modern', split='train')
# Out:
# Resolving data files:   0%|          | 0/154 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]
